# %%
#Assignment Task

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'Roll Number': [2,4,5,3,6,7,8,9,10,1],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Ali', 'Frank', 'Grace', 'Hannah', 'Ian', 'Jack'],
    'Department': ['CS', 'EE', 'CS', 'AI', 'SE', 'AI', 'EE', 'CS', 'SE', 'AI'],
    'Semester': [2,3,4,5,6,7,8,1,2,7],
    'CGPA': [3.85, 3.20, 3.65, 2.90, 3.92, 3.40, 3.10, 3.75, 3.50, 3.80]
    }

# %%
df = pd.DataFrame(data)
df
# Out:
#    Roll Number     Name Department  Semester  CGPA
# 0            2    Alice         CS         2  3.85
# 1            4      Bob         EE         3  3.20
# 2            5  Charlie         CS         4  3.65
# 3            3    David         AI         5  2.90
# 4            6      Ali         SE         6  3.92
# 5            7    Frank         AI         7  3.40
# 6            8    Grace         EE         8  3.10
# 7            9   Hannah         CS         1  3.75
# 8           10      Ian         SE         2  3.50
# 9            1     Jack         AI         7  3.80

# %%
df.head()
# Out:
#    Roll Number     Name Department  Semester  CGPA
# 0            2    Alice         CS         2  3.85
# 1            4      Bob         EE         3  3.20
# 2            5  Charlie         CS         4  3.65
# 3            3    David         AI         5  2.90
# 4            6      Ali         SE         6  3.92

# %%
df.describe()
# Out:
#        Roll Number   Semester       CGPA
# count     10.00000  10.000000  10.000000
# mean       5.50000   4.500000   3.507000
# std        3.02765   2.460804   0.348554
# min        1.00000   1.000000   2.900000
# 25%        3.25000   2.250000   3.250000
# 50%        5.50000   4.500000   3.575000
# 75%        7.75000   6.750000   3.787500
# max       10.00000   8.000000   3.920000

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(df['Name'], df['CGPA'],linewidth=1.2)
plt.title('Student CGPA Comparison')
plt.xlabel('Students')
plt.ylabel('CGPA')
plt.ylim(0, 4.0)
# Out:
# (0.0, 4.0)
